# %% [markdown]
# # Stage D: the published replicationApplies the directional check to the activation-addition weddingdemonstration. Runs on `gpt2-xl`, which the stage loads itself, so themodel named in `run_all` is ignored and only there because the functioniterates over a list. Scored by a word-list rule, so no judge isinvolved.Ungated and small: minutes, not hours. No `HF_TOKEN` needed.**Settings:** Accelerator GPU T4 x2, Internet On.`lbi/published.py` carries the preregistration committing to reporteither outcome, and records the published setting in `ACTADD_SETTING`.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import (    hf_login_if_available, run_all, seed_from_inputs)hf_login_if_available()

# %% [markdown]
# ## 4. Continue an earlier run (optional)Attach a previous run's output under **Add-ons -> Add Input** and this copies its results in, so `resume` skips every concept already finished. Does nothing when nothing is attached, and never overwrites a file this session produced.

# %%
seed_from_inputs()

# %% [markdown]
# ## 5. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"], stages="D")

# %% [markdown]
# ## 6. Package the outputCheck the first lines of the output before walking away:- `commit` should be the head of `main`- `stages` should read `D_published`- stage D prints the `ACTADD_SETTING` it is usingThen download the zip **before the session expires**.

# %%
# !cd /kaggle/working && zip -qr stage_d_published.zip results_published validation_status.json && ls -la stage_d_published.zip
