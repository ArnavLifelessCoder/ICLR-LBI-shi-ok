# %% [markdown]
# # Stage D then E: the replication, then thirty eval promptsTwo stages in one session, cheapest first.**D** re-runs the activation-addition replication on the correcteddirection. It loads `gpt2-xl` itself, so the model named in `run_all` isignored by it. Minutes. Its positive control decides whether thereplication is usable at all, so it goes first and its verdict is thefirst thing to read.**E** re-runs the four judge-scored concepts at thirty eval promptsinstead of six, matching the ground-truth concepts. This removes theconfound in the study's headline comparison: ground truth resolves 6 of40 signs and the judge-scored concepts 4 of 12, but at thirty promptsagainst six, so the gap could be sample size rather than the judge.About three hours, five times stage B.Stage B's six-prompt results are untouched and stay the comparison; theoriginal six prompts are a strict prefix of the thirty.**Settings:** Accelerator GPU T4 x2, Internet On. Ungated: no `HF_TOKEN`.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import (    hf_login_if_available, run_all, seed_from_inputs)hf_login_if_available()

# %% [markdown]
# ## 4. Continue an earlier run (optional)Attach a previous run's output under **Add-ons -> Add Input** and this copies its results in, so `resume` skips every concept already finished. Does nothing when nothing is attached, and never overwrites a file this session produced.

# %%
seed_from_inputs()

# %% [markdown]
# ## 5. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"], stages=["D", "E"])

# %% [markdown]
# ## 6. Package the outputCheck the first lines before walking away:- `commit` should be the head of `main`- `stages` should read `D_published, E_prompts30`- stage E should print `prompts per concept` with **30** for all four,  and it raises rather than running if any still has six- stage D prints `positive control PASSED` or `FAILED`; read that lineThen download the zip **before the session expires**.

# %%
# !cd /kaggle/working && zip -qr prompts30_qwen.zip results_published results_prompts30 validation_status.json && ls -la prompts30_qwen.zip
