# %% [markdown]
# # Stages D and F at the verified ActAdd setting (layer 16)Activation addition at the **verified** published setting, plus thespelling diagnostic for comparison.**What changed.** `ACTADD_SETTING` was checked against arXiv:2308.10248v5Section 4.1, which states the running wedding example as `p+ = weddings`,`p- = ' '`, `l = 16`, `c = 1`. Two recorded values were wrong: the layerwas 6 rather than 16, and the positive prompt was capitalised, which GPT-2tokenises as three tokens instead of one. Every earlier stage D run was acorrectly built vector added at the wrong depth.Algorithm 1 also confirms the harness was already right about two things:the shorter prompt is right-padded to a common token length, and thesteering vector is the position-wise difference rather than a pooled one.**D** sweeps multiples of their coefficient at layer 16, so 1.0 is theirsetting exactly. Its positive control decides whether the replication isusable. **F** repeats the spelling sweep at the corrected layer.Runs on `gpt2-xl`, which the stage loads itself, so the model named in`run_all` is ignored. Under an hour.**Settings:** Accelerator GPU T4 x2, Internet On. Ungated.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import (    hf_login_if_available, run_all, seed_from_inputs)hf_login_if_available()

# %% [markdown]
# ## 4. Continue an earlier run (optional)Attach a previous run's output under **Add-ons -> Add Input** and this copies its results in, so `resume` skips every concept already finished. Does nothing when nothing is attached, and never overwrites a file this session produced.

# %%
seed_from_inputs()

# %% [markdown]
# ## 5. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"], stages=["D", "F"])

# %% [markdown]
# ## 6. Package the outputCheck the first lines before walking away:- `commit` should be the head of `main`- stage D should print the setting with **layer 16** and  **positive_prompt 'weddings'**- read the `positive control PASSED` or `FAILED` line; that is the result- stage F prints one line per spelling, now at layer 16Then download the zip **before the session expires**.

# %%
# !cd /kaggle/working && zip -qr actadd_verified.zip results_published results_contrast_variants validation_status.json && ls -la actadd_verified.zip
