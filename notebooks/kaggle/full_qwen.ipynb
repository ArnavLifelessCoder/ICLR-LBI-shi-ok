# %% [markdown]
# # Full validation run: Qwen2.5-7B-InstructStages C, B and A on one model, cheapest first, so a session killed bythe wall clock still returns the cheap results.About six hours. **One model per session**: three do not fit in twelve.**Settings:** Accelerator GPU T4 x2, Internet On.Ungated: no secret needed.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import hf_login_if_available, run_allhf_login_if_available()

# %% [markdown]
# ## 4. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"])

# %% [markdown]
# ## 5. Package the outputCheck the first lines before walking away:- `commit` should be the head of `main`- `stage A grid` should read **13 points**- `stages` should read `C_ksweep, D_published, B_rejudge, A_groundtruth`Then download the zip **before the session expires**. That is how thefirst Qwen and Mistral ground-truth results were lost.

# %%
# !cd /kaggle/working && zip -qr full_qwen.zip results_groundtruth results_rejudge results_ksweep validation_status.json && ls -la full_qwen.zip
