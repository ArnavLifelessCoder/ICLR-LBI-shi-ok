# %% [markdown]
# # Stages F, D and E: the spelling diagnostic, then thirty promptsThree stages in one session, cheapest first.**F** sweeps six spellings of the activation-addition contrast on`gpt2-xl`. Stage D has had three harness bugs fixed and still fails itspositive control, and the remaining suspect is the recorded contraststring itself: GPT-2 tokenises `Weddings`, ` Weddings` and ` weddings`differently. If none reproduces the effect the null is robust; if onedoes, that is a recording error to verify against the paper, not aresult. Minutes.**D** re-runs the replication at the recorded setting, now savingper-prompt scores. Minutes.**E** re-runs the four judge-scored concepts at thirty eval prompts,also saving per-prompt scores. The first stage E run produced thecomparison but not the data to make it cleanly: the thirty-prompt setmoved the baselines (sentiment 0.833 to 0.400), so six-versus-thirtywas not a pure prompt-count comparison. With per-prompt scores thefirst six of the same thirty can be subset offline, holding the run,the judge and the generations fixed. About three hours.**Settings:** Accelerator GPU T4 x2, Internet On. Ungated: no `HF_TOKEN`.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import (    hf_login_if_available, run_all, seed_from_inputs)hf_login_if_available()

# %% [markdown]
# ## 4. Continue an earlier run (optional)Attach a previous run's output under **Add-ons -> Add Input** and this copies its results in, so `resume` skips every concept already finished. Does nothing when nothing is attached, and never overwrites a file this session produced.

# %%
seed_from_inputs()

# %% [markdown]
# ## 5. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"], stages=["F", "D", "E"])

# %% [markdown]
# ## 6. Package the outputCheck the first lines before walking away:- `commit` should be the head of `main`- `stages` should read `D_published, E_prompts30, F_variants`- stage F prints one line per spelling ending `CONTROL PASSED` or  `control failed`; that block is the whole result- stage E should print `prompts per concept` with **30** for all fourThen download the zip **before the session expires**.

# %%
# !cd /kaggle/working && zip -qr round2_qwen.zip results_contrast_variants results_published results_prompts30 validation_status.json && ls -la round2_qwen.zip
