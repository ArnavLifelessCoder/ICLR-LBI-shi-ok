# %% [markdown]
# # Stage G: ten judge-scored concepts, matched protocol (Qwen2.5-7B-Instruct)The ten judge-scored concepts, measured exactly as the ten rule-scoredones are: single layer, thirteen-point grid, thirty evaluation prompts,intervals for the mean.**Why.** The paper's headline compares how often a directional signresolves under a rule readout against under a judge. Until now the twosides were measured differently, so the gap was partly a protocoldifference. This makes it forty points against forty with the readout asthe only variable.All ten concepts now carry thirty evaluation prompts, the original sixkept as a strict prefix so the earlier numbers are recoverable bysubsetting.About four hours: 3,900 generations, each scored by the judge.Results go to `results_judge_matched`, leaving every earlier directoryuntouched.**Settings:** Accelerator GPU T4 x2 preferred, Internet On. The judge nowfalls back across GPUs and then to CPU, so one GPU still finishes.Ungated: no `HF_TOKEN` needed.

# %% [markdown]
# ## 1. CloneDeletes the checkout first so the clone actually refreshes, and prints the commit that ran.

# %%
# !rm -rf /kaggle/working/lbi-repo && GIT_TERMINAL_PROMPT=0 git clone -q https://github.com/ArnavLifelessCoder/ICLR-LBI-shi-ok.git /kaggle/working/lbi-repo && git -C /kaggle/working/lbi-repo log --oneline -1

# %% [markdown]
# ## 2. Dependencies

# %%
# !pip install -q -U transformers accelerate bitsandbytes

# %% [markdown]
# ## 3. Import and log inThe login degrades to a printed note when no secret is attached, rather than raising.

# %%
import sys; sys.path.insert(0, "/kaggle/working/lbi-repo")from notebooks.run_kaggle_validation import (    hf_login_if_available, run_all, seed_from_inputs)hf_login_if_available()

# %% [markdown]
# ## 4. Continue an earlier run (optional)Attach a previous run's output under **Add-ons -> Add Input** and this copies its results in, so `resume` skips every concept already finished. Does nothing when nothing is attached, and never overwrites a file this session produced.

# %%
seed_from_inputs()

# %% [markdown]
# ## 5. Run

# %%
status = run_all(["Qwen/Qwen2.5-7B-Instruct"], stages=["G"])

# %% [markdown]
# ## 6. Package the outputCheck the first lines before walking away:- `commit` should be the head of `main`- `per-generation scores: recorded` must appear- stage G should print `10 concepts, single layer` and  `prompts per concept` with **30** for all ten- it should say `10 of 10 concepts are at thirty prompts`Then download the zip **before the session expires**.

# %%
# !cd /kaggle/working && zip -qr matched_qwen.zip results_judge_matched validation_status.json && ls -la matched_qwen.zip
